# %%
import numpy as np

# %%
s = np.full((3, 3), ".")

# %%
print(s)
# Out:
# [['.' '.' '.']
#  ['.' '.' '.']
#  ['.' '.' '.']]

# %%
s[0,0] = "X"

# %%
print(s)
# Out:
# [['X' '.' '.']
#  ['.' '.' '.']
#  ['.' '.' '.']]

# %%
import os

# %%
os.getcwd()
# Out:
# '/home/newir529/SOFTWARE_DEVELPMENT/PYTHON/TicTacToe/GAME_UI'

# %%
os.listdir()
# Out:
# ['TicTacToe.ipynb', 'test.ipynb', 'game.py']

# %%
import sys

name = sys.argv[0]

# %%
name
# Out:
# '/usr/lib/python3/dist-packages/ipykernel_launcher.py'
