# %%
import numpy as np

# %%
s = np.full((3, 3), ".")

# %%
print(s)
# Out:
# [['.' '.' '.']
#  ['.' '.' '.']
#  ['.' '.' '.']]

# %%
s[0,0] = "X"

# %%
print(s)
# Out:
# [['X' '.' '.']
#  ['.' '.' '.']
#  ['.' '.' '.']]
